# %%
#Metodos Computacionales 
#Tarea 5 
#Jesus Solano - David Jaramillo

# %%
# %pylab inline

import matplotlib.pyplot as plt
from scipy.fftpack import fft, fftfreq
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Im1 = pylab.imread("colesterol-1.tif")
fig = figure(1, figsize=(10.5,8.5))
imshow(Im1[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)

print shape(Im1)
# Out:
# (244, 357)

# %%
Im2 = pylab.imread("ves_full_150_002-1.tif")
fig = figure(1, figsize=(10.5,8.5))
imshow(Im2[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)

# %%
print  shape(Im1)

fftIm1 = [[ 0 for row in range(357) ] for col in range(244)]

print shape(fftIm1)

"""#Ahora hacemos la transformada. 

T1= rfft2(Im1)

#T1[0, 0] = 0 
# Quita la entrada incial.
freq= abs(T1)

f1shift= fftshift(T1)


espectro= log(abs(f1shift))

plt.imshow(abs(f1shift))

plt.imshow(espectro, cmap = 'gray')"""

Tr1= fft2(Im1)

Tr1_mag= abs(fftshift(Tr1))
Tr1_phase= angle(fftshift(Tr1))

imshow(log(Tr1_mag))

#imshow(Tr1_phase)
# Out:
# (244, 357)
# (244, 357)

# %%
#FiltroBajas

Tr1_Or=fftshift(Tr1)

frefil = numpy.zeros(Tr1.shape, dtype=numpy.complex128)

frac = 0.25
rad = frac*int(min(Tr1.shape)/2)

ic = Tr1.shape[0]/2
jc = Tr1.shape[1]/2

for i in range(Tr1.shape[0]):
    for j in range(Tr1.shape[1]):

        if math.sqrt( (i-ic)**2 + (j-jc)**2) < rad:
            frefil[i,j] = Tr1_Or[i,j]
            

im1_fil = real(ifft2(ifftshift(frefil)))

imshow(im1_fil,  cmap=matplotlib.cm.Greys_r)

#imshow(im1_fil)

# %%
#Ahora aplicamos un filtro para bajas.

Tr1_Or=fftshift(Tr1)

frefil = numpy.zeros(Tr1.shape, dtype=numpy.complex128)

frac = 0.05
rad = frac*int(min(Tr1.shape)/2)

ic = Tr1.shape[0]/2
jc = Tr1.shape[1]/2

for i in range(Tr1.shape[0]):
    for j in range(Tr1.shape[1]):

        if math.sqrt( (i-ic)**2 + (j-jc)**2) > rad:
            frefil[i,j] = Tr1_Or[i,j]
            

im1_filbaja = abs(ifft2(ifftshift(frefil)))

imshow(im1_filbaja,  cmap=matplotlib.cm.Greys_r)

# %%
#FiltroBajas ahora un poco mas suave.


Tr1_Or=fftshift(Tr1)

frefil = numpy.zeros(Tr1.shape, dtype=numpy.complex128)

frefnor = numpy.zeros(Tr1.shape, dtype=numpy.complex128)

frac = 0.25
rad = frac*int(min(Tr1.shape)/2)


rad=0.2

ic = Tr1.shape[0]/2
jc = Tr1.shape[1]/2

"""
for i in range(Tr1.shape[0]):
    for j in range(Tr1.shape[1]):

        frefil[i,j] = (1/(2*pi*(rad**2)))*(exp(-1*(((i-ic)**2+(j-jc)**2)/(2*pi*(rad**2)))))
        max = frefil.max()
        frefnor[i,j]= abs(frefil[i,j]) / max * Tr1_Or[i,j]

"""

for i in range(Tr1.shape[0]):
    for j in range(Tr1.shape[1]):
        if(i>= ic):
            if(j>=jc):
                    
                frefil[i,j] = 1
            if(j<=jc):
                frefil[i,j] = 1



im1_fil = real(ifft2(ifftshift(frefnor)))

im1_fil2 = real(ifft2(frefnor))

imshow(abs(frefnor),  cmap=matplotlib.cm.Greys_r)

#imshow(im1_fil)

print min(Tr1.shape)
# Out:
# (1+0j)
# 244

# %%
#FiltroAltas ahora un poco mas suave.


Tr1_Or=fftshift(Tr1)

frefil = numpy.zeros(Tr1.shape, dtype=numpy.complex128)

frac = 0.02

rad = frac*int(min(Tr1.shape)/2)

rad = 2

ic = Tr1.shape[0]/2
jc = Tr1.shape[1]/2

for i in range(Tr1.shape[0]):
     frefil[i,:] = Tr1_Or[i,:]*(1 - exp((-(i-ic)**2)/(2*(rad)**2)))

for j in range(Tr1.shape[1]):
     frefil[:,j] = Tr1_Or[:,j]*(1 - exp((-(j-jc)**2)/(2*(rad)**2)))

im1_fil = real(ifft2(ifftshift(frefil)))

imshow(im1_fil,  cmap=matplotlib.cm.Greys_r)

# %%
img = plt.imread('full_moon.jpg')
plt.imshow(img)

print shape(img)
# Out:
# (296, 300, 3)
