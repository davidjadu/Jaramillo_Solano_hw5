# %%
# %pylab inline
from scipy.fftpack import fftfreq, fft
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.loadtxt('circulos.dat')
x=data[:,0]
y=data[:,1]

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

ax.scatter(x, y, alpha=0.5, s=1)

# %%
points = 1024
h=6.0/points
intensity=zeros((points,points))
for k in range(len(x)):
    intensity[int(y[k]/h), int(x[k]/h)]+=1.0

# %%
intensity_fft = fft2(intensity)
correlation_fft = fftshift(intensity_fft*intensity_fft.conjugate())
freq = fftshift(fftfreq(points,h))

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

im = ax.imshow(log(abs(correlation_fft)), origin='lower')
ax.set_title('log(Fourier transform)')
fig.colorbar(im, ax=ax)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f701d1dc098>

# %%
center = points/2
k1d=freq[freq>=0]
intensity1d_fft=zeros(points/2+1)
num=zeros(points/2+1)
for i in range(points):
    for j in range(points):
        k= int(sqrt((i-center)**2+(j-center)**2))
        if (k<=points/2):
            intensity1d_fft[k]+=abs(intensity_fft[i,j])
            num[k]+=1

# %%
intensity1d_fft=intensity1d_fft/num

# %%
plot(intensity1d_fft[:-1])

# %%
import operator
maximum,val= index, value = max(enumerate(intensity1d_fft[80:100]), key=operator.itemgetter(1))
maximum+=80

# %%
plot(intensity1d_fft[:-1])
scatter(maximum,val, color ='r')

# %%
radius=maximum*h

# %%
print radius
# Out:
# 0.57421875
